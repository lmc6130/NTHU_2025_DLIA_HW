# %% [markdown]
# <div align="center">
#
# #### Lab 3
#
# # National Tsing Hua University
#
# #### Spring 2025
#
# #### 11320IEEM 513600
#
# #### Deep Learning and Industrial Applications
#
# ## Lab 3: Anomaly Detection in Industrial Applications
#
# </div>

# %% [markdown]
# ### Introduction
#
# In today's industrial landscape, the ability to detect anomalies in manufacturing processes and products is critical for maintaining quality, efficiency, and safety. This lab focuses on leveraging deep learning techniques for anomaly detection in various industrial applications, using the MVTEC Anomaly Detection Dataset. By employing ImageNet-pretrained models available in torchvision, students will gain hands-on experience in classfying defects and irregularities across different types of industrial products.
#
# Throughout this lab, you'll be involved in the following key activities:
# - Explore and process the MVTec Anomaly Detection Dataset.
# - Apply ImageNet-pretrained models from [Torchvision](https://pytorch.org/vision/stable/models.html) to detect anomalies in industrial products.
# - Evaluate the performance of the models to understand their effectiveness in real-world industrial applications.
#
# ### Objectives
#
# - Understand the principles of anomaly detection in the context of industrial applications.
# - Learn how to implement and utilize ImageNet-pretrained models for detecting anomalies.
# - Analyze and interpret the results of the anomaly detection models to assess their practicality in industrial settings.
#
# ### Dataset
#
# The MVTec AD Dataset is a comprehensive collection of high-resolution images across different categories of industrial products, such as bottles, cables, and metal nuts, each with various types of defects. This dataset is pivotal for developing and benchmarking anomaly detection algorithms. You can download our lab's dataset [here](https://drive.google.com/file/d/19600hUOpx0hl78TdpdH0oyy-gGTk_F_o/view?usp=share_link). You can drop downloaded data and drop to colab, or you can put into yor google drive.
#
# ### References
# - [MVTec AD Dataset](https://www.kaggle.com/datasets/ipythonx/mvtec-ad/data) for the dataset used in this lab.
# - [Torchvision Models](https://pytorch.org/vision/stable/models.html) for accessing ImageNet-pretrained models to be used in anomaly detection tasks.
# - [State-of-the-Art Anomaly Detection on MVTec AD](https://paperswithcode.com/sota/anomaly-detection-on-mvtec-ad) for insights into the latest benchmarks and methodologies in anomaly detection applied to the MVTec AD dataset.
# - [CVPR 2019: MVTec AD — A Comprehensive Real-World Dataset for Unsupervised Anomaly Detection] for the original paper of MVTec AD dataset.

# %%
import cv2
import glob
import matplotlib.pyplot as plt
import numpy as np
import os
import random
from tqdm.auto import tqdm
from google.colab import drive

drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/PhD/113 DLIA/HW3/MVTec AD Dataset/tile')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_paths = glob.glob('test/**/*.png', recursive=True)
file_paths.sort()

# 打印文件路径
for path in file_paths:
    print(path)
# Out:
# test/crack/000.png
# test/crack/001.png
# test/crack/002.png
# test/crack/003.png
# test/crack/004.png
# test/crack/005.png
# test/crack/006.png
# test/crack/007.png
# test/crack/008.png
# test/crack/009.png
# test/crack/010.png
# test/crack/011.png
# test/crack/012.png
# test/crack/013.png
# test/crack/014.png
# test/crack/015.png
# test/crack/016.png
# test/glue_strip/000.png
# test/glue_strip/001.png
# test/glue_strip/002.png
# test/glue_strip/003.png
# test/glue_strip/004.png
# test/glue_strip/005.png
# test/glue_strip/006.png
# test/glue_strip/007.png
# test/glue_strip/008.png
# test/glue_strip/009.png
# test/glue_strip/010.png
# test/glue_strip/011.png
# test/glue_strip/012.png
# test/glue_strip/013.png
# test/glue_strip/014.png
# test/glue_strip/015.png
# test/glue_strip/016.png
# test/glue_strip/017.png
# test/good/000.png
# test/good/001.png
# test/good/002.png
# test/good/003.png
# test/good/004.png
# test/good/005.png
# test/good/006.png
# test/good/007.png
# test/good/008.png
# test/good/009.png
# test/good/010.png
# test/good/011.png
# test/good/012.png
# test/good/013.png
# test/good/014.png
# test/good/015.png
# test/good/016.png
# test/good/017.png
# test/good/018.png
# test/good/019.png
# test/good/020.png
# test/good/021.png
# test/good/022.png
# test/good/023.png
# test/good/024.png
# test/good/025.png
# test/good/026.png
# test/good/027.png
# test/good/028.png
# test/good/029.png
# test/good/030.png
# test/good/031.png
# test/good/032.png
# test/gray_stroke/000.png
# test/gray_stroke/001.png
# test/gray_stroke/002.png
# test/gray_stroke/003.png
# test/gray_stroke/004.png
# test/gray_stroke/005.png
# test/gray_stroke/006.png
# test/gray_stroke/007.png
# test/gray_stroke/008.png
# test/gray_stroke/009.png
# test/gray_stroke/010.png
# test/gray_stroke/011.png
# test/gray_stroke/012.png
# test/gray_stroke/013.png
# test/gray_stroke/014.png
# test/gray_stroke/015.png
# test/oil/000.png
# test/oil/001.png
# test/oil/002.png
# test/oil/003.png
# test/oil/004.png
# test/oil/005.png
# test/oil/006.png
# test/oil/007.png
# test/oil/008.png
# test/oil/009.png
# test/oil/010.png
# test/oil/011.png
# test/oil/012.png
# test/oil/013.png
# test/oil/014.png
# test/oil/015.png
# test/oil/016.png
# test/oil/017.png
# test/rough/000.png
# test/rough/001.png
# test/rough/002.png
# test/rough/003.png
# test/rough/004.png
# test/rough/005.png
# test/rough/006.png
# test/rough/007.png
# test/rough/008.png
# test/rough/009.png
# test/rough/010.png
# test/rough/011.png
# test/rough/012.png
# test/rough/013.png
# test/rough/014.png

# %%
all_data = []

for img in tqdm(file_paths):
    img = cv2.imread(img)
    img = img[..., ::-1]
    all_data.append(img)

all_data = np.stack(all_data)
print(all_data.shape)
# Out:
#   0%|          | 0/117 [00:00<?, ?it/s]
# (117, 840, 840, 3)

# %%
import matplotlib.pyplot as plt
import numpy as np

classes = sorted(set([path.split('/')[1] for path in file_paths]))
print(f'Classes: {classes}')

images_per_class = len(all_data) // len(classes)
fig, axs = plt.subplots(len(classes), 2, figsize=(6, 4 * len(classes)))

for i, class_name in enumerate(classes):
    index = i * images_per_class
    for j in range(2):
        axs[i, j].set_title(f'{i}. {class_name}')
        axs[i, j].imshow(all_data[index + j])
        axs[i, j].axis('off')

plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## A. Data Loading and Preprocessing

# %%
import torch
from torch.utils.data import DataLoader, TensorDataset, random_split
import numpy as np

num_classes = 7
images_per_class = 15
train_images_per_class = int(images_per_class * 0.8)
val_images_per_class = int(images_per_class * 0.2)

x_train = []
x_val = []

for i in range(num_classes):
    start_index = i * images_per_class
    x_train.extend(all_data[start_index:start_index + train_images_per_class])
    x_val.extend(all_data[start_index + train_images_per_class:start_index + images_per_class])

# The shape changes from (batch_size, height, width, channels) to (batch_size, channels, height, width)
x_train = np.transpose(np.array(x_train), (0, 3, 1, 2))
x_val = np.transpose(np.array(x_val), (0, 3, 1, 2))

y_train = np.concatenate([np.full(train_images_per_class, i) for i in range(num_classes)])
y_val = np.concatenate([np.full(val_images_per_class, i) for i in range(num_classes)])

print(f'Shape of x_train: {x_train.shape}')
print(f'Shape of x_val: {x_val.shape}')
print(f'Shape of y_train: {y_train.shape}')
print(f'Shape of y_val: {y_val.shape}')
# Out:
# Shape of x_train: (84, 3, 840, 840)
# Shape of x_val: (21, 3, 840, 840)
# Shape of y_train: (84,)
# Shape of y_val: (21,)

# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image

train_transforms = transforms.Compose(
    [
        transforms.Resize((32, 32)),
        transforms.AutoAugment(),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
    ]
)

val_transforms = transforms.Compose(
    [
        transforms.Resize((32, 32)),
        transforms.ToTensor(),
    ]
)

class MyDataset(Dataset):
    def __init__(self, x, y, transform=None):
        self.x = x
        self.y = torch.from_numpy(y).long()
        self.transform = transform

    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        new_x = np.transpose(self.x[idx], (1, 2, 0))
        return self.transform(Image.fromarray(new_x)), self.y[idx]

# %%
batch_size = 64

train_dataset = MyDataset(x_train, y_train, train_transforms)
val_dataset = MyDataset(x_val, y_val, val_transforms)

train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True, num_workers=2, pin_memory=True, persistent_workers=True)
val_loader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False, num_workers=1, pin_memory=True, persistent_workers=True)

# %% [markdown]
# ## B. Defining Neural Networks

# %%
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models

model = models.resnet18(weights='IMAGENET1K_V1')

# ConvNet as fixed feature extractor (freeze parameters)
for param in model.parameters():
    param.requires_grad = False

num_ftrs = model.fc.in_features
num_class = 7

# change # of class from 1000 into 8 in the last layer
model.fc = nn.Linear(num_ftrs, num_class)
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=7, bias=True)
# )

# %% [markdown]
# ## C. Training the Neural Network

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR, StepLR
from tqdm.auto import tqdm

train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

epochs = 100
model = model.cuda()

best_val_loss = float('inf')
best_val_acc = -1

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)
lr_scheduler = CosineAnnealingLR(optimizer, T_max=len(train_loader)*epochs, eta_min=0)

for epoch in tqdm(range(epochs)):
    # Training
    model.train()
    total_loss = 0.0
    train_correct = 0
    total_train_samples = 0

    for images, labels in train_loader:
        images = images.cuda()
        images = (images) / 255.
        labels = labels.cuda()
        optimizer.zero_grad()
        outputs = model(images)

        labels = labels.long()

        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

        train_predicted = outputs.argmax(-1)
        train_correct += (train_predicted == labels).sum().item()
        total_train_samples += labels.size(0)

    avg_train_loss = total_loss / len(train_loader)
    train_accuracy = 100. * train_correct / total_train_samples

    # Validation
    model.eval()
    total_val_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in val_loader:
            images = images.cuda()
            images = (images) / 255.
            labels = labels.cuda()
            outputs = model(images)

            labels = labels.long()

            loss = criterion(outputs, labels)
            total_val_loss += loss.item()

            predicted = outputs.argmax(-1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

    avg_val_loss = total_val_loss / len(val_loader)
    val_accuracy = 100. * correct / total

    # Learning rate update
    lr_scheduler.step()

    # Checkpoint
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss

    if val_accuracy > best_val_acc:
        best_val_acc = val_accuracy
        torch.save(model.state_dict(), 'model_classification.pth')

    print(f'Epoch {epoch+1}/{epochs}, Train loss: {avg_train_loss:.4f}, Train acc: {train_accuracy:.4f}%, Val loss: {avg_val_loss:.4f}, Val acc: {val_accuracy:.4f}%, Best Val loss: {best_val_loss:.4f} Best Val acc: {best_val_acc:.2f}%')

    # Store performance
    train_losses.append(avg_train_loss)
    train_accuracies.append(train_accuracy)
    val_losses.append(avg_val_loss)
    val_accuracies.append(val_accuracy)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 1/100, Train loss: 2.1547, Train acc: 15.4762%, Val loss: 1.9656, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 2/100, Train loss: 2.1025, Train acc: 13.0952%, Val loss: 1.9713, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 3/100, Train loss: 1.9733, Train acc: 20.2381%, Val loss: 1.9763, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 4/100, Train loss: 1.9322, Train acc: 21.4286%, Val loss: 1.9867, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 5/100, Train loss: 1.9300, Train acc: 26.1905%, Val loss: 1.9969, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 6/100, Train loss: 1.8948, Train acc: 29.7619%, Val loss: 2.0192, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 7/100, Train loss: 1.9343, Train acc: 23.8095%, Val loss: 2.0381, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 8/100, Train loss: 1.9530, Train acc: 22.6190%, Val loss: 2.0541, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 9/100, Train loss: 1.9634, Train acc: 23.8095%, Val loss: 2.0987, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 10/100, Train loss: 1.9952, Train acc: 22.6190%, Val loss: 2.1817, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 11/100, Train loss: 1.9243, Train acc: 26.1905%, Val loss: 2.3939, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 12/100, Train loss: 1.7447, Train acc: 28.5714%, Val loss: 2.4578, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 13/100, Train loss: 1.7735, Train acc: 29.7619%, Val loss: 2.4264, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 14/100, Train loss: 1.8805, Train acc: 28.5714%, Val loss: 2.5022, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 15/100, Train loss: 1.8241, Train acc: 26.1905%, Val loss: 2.4401, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 16/100, Train loss: 1.7733, Train acc: 35.7143%, Val loss: 2.5265, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 17/100, Train loss: 1.7285, Train acc: 36.9048%, Val loss: 2.4164, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 18/100, Train loss: 1.8034, Train acc: 27.3810%, Val loss: 2.6586, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 19/100, Train loss: 1.7616, Train acc: 32.1429%, Val loss: 2.4826, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 20/100, Train loss: 1.6740, Train acc: 32.1429%, Val loss: 2.3430, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 21/100, Train loss: 1.7190, Train acc: 25.0000%, Val loss: 2.2746, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 22/100, Train loss: 1.7438, Train acc: 35.7143%, Val loss: 2.3454, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 23/100, Train loss: 1.7766, Train acc: 38.0952%, Val loss: 2.6475, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 24/100, Train loss: 1.6193, Train acc: 35.7143%, Val loss: 2.4786, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 25/100, Train loss: 1.6590, Train acc: 34.5238%, Val loss: 2.6288, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 26/100, Train loss: 1.7379, Train acc: 38.0952%, Val loss: 3.0632, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 27/100, Train loss: 1.7484, Train acc: 29.7619%, Val loss: 2.9731, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 28/100, Train loss: 1.6075, Train acc: 32.1429%, Val loss: 3.0708, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 29/100, Train loss: 1.5867, Train acc: 34.5238%, Val loss: 3.3115, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 30/100, Train loss: 1.5885, Train acc: 41.6667%, Val loss: 3.5598, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 31/100, Train loss: 1.6658, Train acc: 36.9048%, Val loss: 3.7039, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 32/100, Train loss: 1.4374, Train acc: 50.0000%, Val loss: 3.4653, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 33/100, Train loss: 1.6860, Train acc: 29.7619%, Val loss: 3.7609, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 34/100, Train loss: 1.6523, Train acc: 44.0476%, Val loss: 4.0403, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 35/100, Train loss: 1.7074, Train acc: 34.5238%, Val loss: 4.3367, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 36/100, Train loss: 1.6080, Train acc: 33.3333%, Val loss: 3.9943, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 37/100, Train loss: 1.5203, Train acc: 45.2381%, Val loss: 3.3800, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 38/100, Train loss: 1.4998, Train acc: 42.8571%, Val loss: 2.9744, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 39/100, Train loss: 1.7415, Train acc: 30.9524%, Val loss: 2.8064, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 40/100, Train loss: 1.5693, Train acc: 39.2857%, Val loss: 2.7607, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 41/100, Train loss: 1.5661, Train acc: 30.9524%, Val loss: 2.6748, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 42/100, Train loss: 1.5442, Train acc: 38.0952%, Val loss: 2.9756, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 43/100, Train loss: 1.5033, Train acc: 41.6667%, Val loss: 3.1542, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 44/100, Train loss: 1.7237, Train acc: 30.9524%, Val loss: 3.2655, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 45/100, Train loss: 1.5875, Train acc: 35.7143%, Val loss: 2.6960, Val acc: 9.5238%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 46/100, Train loss: 1.5691, Train acc: 34.5238%, Val loss: 2.3655, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 47/100, Train loss: 1.5298, Train acc: 38.0952%, Val loss: 2.3318, Val acc: 9.5238%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 48/100, Train loss: 1.4312, Train acc: 46.4286%, Val loss: 2.2096, Val acc: 9.5238%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 49/100, Train loss: 1.6396, Train acc: 36.9048%, Val loss: 2.2054, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 50/100, Train loss: 1.6012, Train acc: 38.0952%, Val loss: 2.1980, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 14.29%
# Epoch 51/100, Train loss: 1.4482, Train acc: 44.0476%, Val loss: 2.1821, Val acc: 19.0476%, Best Val loss: 1.9656 Best Val acc: 19.05%
# Epoch 52/100, Train loss: 1.5373, Train acc: 39.2857%, Val loss: 2.1791, Val acc: 19.0476%, Best Val loss: 1.9656 Best Val acc: 19.05%
# Epoch 53/100, Train loss: 1.5857, Train acc: 39.2857%, Val loss: 2.1944, Val acc: 19.0476%, Best Val loss: 1.9656 Best Val acc: 19.05%
# Epoch 54/100, Train loss: 1.5298, Train acc: 42.8571%, Val loss: 2.2256, Val acc: 19.0476%, Best Val loss: 1.9656 Best Val acc: 19.05%
# Epoch 55/100, Train loss: 1.3038, Train acc: 52.3810%, Val loss: 2.2266, Val acc: 14.2857%, Best Val loss: 1.9656 Best Val acc: 19.05%
# Epoch 56/100, Train loss: 1.6314, Train acc: 44.0476%, Val loss: 2.2000, Val acc: 19.0476%, Best Val loss: 1.9656 Best Val acc: 19.05%
# Epoch 57/100, Train loss: 1.5696, Train acc: 40.4762%, Val loss: 2.1601, Val acc: 19.0476%, Best Val loss: 1.9656 Best Val acc: 19.05%
# Epoch 58/100, Train loss: 1.5685, Train acc: 40.4762%, Val loss: 2.2034, Val acc: 19.0476%, Best Val loss: 1.9656 Best Val acc: 19.05%
# Epoch 59/100, Train loss: 1.5344, Train acc: 41.6667%, Val loss: 2.1483, Val acc: 19.0476%, Best Val loss: 1.9656 Best Val acc: 19.05%
# Epoch 60/100, Train loss: 1.6208, Train acc: 36.9048%, Val loss: 2.0788, Val acc: 19.0476%, Best Val loss: 1.9656 Best Val acc: 19.05%
# Epoch 61/100, Train loss: 1.4465, Train acc: 48.8095%, Val loss: 2.1125, Val acc: 19.0476%, Best Val loss: 1.9656 Best Val acc: 19.05%
# Epoch 62/100, Train loss: 1.6128, Train acc: 44.0476%, Val loss: 2.0988, Val acc: 19.0476%, Best Val loss: 1.9656 Best Val acc: 19.05%
# Epoch 63/100, Train loss: 1.4144, Train acc: 45.2381%, Val loss: 2.1277, Val acc: 23.8095%, Best Val loss: 1.9656 Best Val acc: 23.81%
# Epoch 64/100, Train loss: 1.5791, Train acc: 42.8571%, Val loss: 2.1322, Val acc: 23.8095%, Best Val loss: 1.9656 Best Val acc: 23.81%
# Epoch 65/100, Train loss: 1.6848, Train acc: 47.6190%, Val loss: 2.0868, Val acc: 28.5714%, Best Val loss: 1.9656 Best Val acc: 28.57%
# Epoch 66/100, Train loss: 1.5403, Train acc: 38.0952%, Val loss: 2.1115, Val acc: 28.5714%, Best Val loss: 1.9656 Best Val acc: 28.57%
# Epoch 67/100, Train loss: 1.7191, Train acc: 32.1429%, Val loss: 2.0816, Val acc: 23.8095%, Best Val loss: 1.9656 Best Val acc: 28.57%
# Epoch 68/100, Train loss: 1.3871, Train acc: 50.0000%, Val loss: 2.1001, Val acc: 23.8095%, Best Val loss: 1.9656 Best Val acc: 28.57%
# Epoch 69/100, Train loss: 1.4800, Train acc: 47.6190%, Val loss: 2.1254, Val acc: 9.5238%, Best Val loss: 1.9656 Best Val acc: 28.57%
# Epoch 70/100, Train loss: 1.3802, Train acc: 52.3810%, Val loss: 2.0994, Val acc: 9.5238%, Best Val loss: 1.9656 Best Val acc: 28.57%
# Epoch 71/100, Train loss: 1.4859, Train acc: 41.6667%, Val loss: 2.0927, Val acc: 9.5238%, Best Val loss: 1.9656 Best Val acc: 28.57%
# Epoch 72/100, Train loss: 1.5652, Train acc: 35.7143%, Val loss: 2.1497, Val acc: 19.0476%, Best Val loss: 1.9656 Best Val acc: 28.57%
# Epoch 73/100, Train loss: 1.4249, Train acc: 39.2857%, Val loss: 2.1231, Val acc: 23.8095%, Best Val loss: 1.9656 Best Val acc: 28.57%
# Epoch 74/100, Train loss: 1.4508, Train acc: 40.4762%, Val loss: 2.1389, Val acc: 23.8095%, Best Val loss: 1.9656 Best Val acc: 28.57%
# Epoch 75/100, Train loss: 1.6268, Train acc: 48.8095%, Val loss: 2.2140, Val acc: 28.5714%, Best Val loss: 1.9656 Best Val acc: 28.57%
# Epoch 76/100, Train loss: 1.6791, Train acc: 50.0000%, Val loss: 2.1916, Val acc: 28.5714%, Best Val loss: 1.9656 Best Val acc: 28.57%
# Epoch 77/100, Train loss: 1.4235, Train acc: 41.6667%, Val loss: 2.2296, Val acc: 33.3333%, Best Val loss: 1.9656 Best Val acc: 33.33%
# Epoch 78/100, Train loss: 1.5528, Train acc: 40.4762%, Val loss: 2.2417, Val acc: 33.3333%, Best Val loss: 1.9656 Best Val acc: 33.33%
# Epoch 79/100, Train loss: 1.4543, Train acc: 47.6190%, Val loss: 2.2014, Val acc: 28.5714%, Best Val loss: 1.9656 Best Val acc: 33.33%
# Epoch 80/100, Train loss: 1.5009, Train acc: 41.6667%, Val loss: 2.1582, Val acc: 23.8095%, Best Val loss: 1.9656 Best Val acc: 33.33%
# Epoch 81/100, Train loss: 1.3988, Train acc: 50.0000%, Val loss: 2.2348, Val acc: 23.8095%, Best Val loss: 1.9656 Best Val acc: 33.33%
# Epoch 82/100, Train loss: 1.4935, Train acc: 42.8571%, Val loss: 2.2402, Val acc: 23.8095%, Best Val loss: 1.9656 Best Val acc: 33.33%
# Epoch 83/100, Train loss: 1.5766, Train acc: 45.2381%, Val loss: 2.2500, Val acc: 23.8095%, Best Val loss: 1.9656 Best Val acc: 33.33%
# Epoch 84/100, Train loss: 1.5194, Train acc: 42.8571%, Val loss: 2.1988, Val acc: 23.8095%, Best Val loss: 1.9656 Best Val acc: 33.33%
# Epoch 85/100, Train loss: 1.6460, Train acc: 50.0000%, Val loss: 2.2258, Val acc: 23.8095%, Best Val loss: 1.9656 Best Val acc: 33.33%
# Epoch 86/100, Train loss: 1.4105, Train acc: 52.3810%, Val loss: 2.2435, Val acc: 23.8095%, Best Val loss: 1.9656 Best Val acc: 33.33%
# Epoch 87/100, Train loss: 1.6404, Train acc: 42.8571%, Val loss: 2.2205, Val acc: 28.5714%, Best Val loss: 1.9656 Best Val acc: 33.33%
# Epoch 88/100, Train loss: 1.5324, Train acc: 36.9048%, Val loss: 2.1928, Val acc: 33.3333%, Best Val loss: 1.9656 Best Val acc: 33.33%
# Epoch 89/100, Train loss: 1.5734, Train acc: 44.0476%, Val loss: 2.2356, Val acc: 33.3333%, Best Val loss: 1.9656 Best Val acc: 33.33%
# Epoch 90/100, Train loss: 1.5528, Train acc: 39.2857%, Val loss: 2.2185, Val acc: 38.0952%, Best Val loss: 1.9656 Best Val acc: 38.10%
# Epoch 91/100, Train loss: 1.4450, Train acc: 47.6190%, Val loss: 2.2535, Val acc: 28.5714%, Best Val loss: 1.9656 Best Val acc: 38.10%
# Epoch 92/100, Train loss: 1.5258, Train acc: 36.9048%, Val loss: 2.2270, Val acc: 28.5714%, Best Val loss: 1.9656 Best Val acc: 38.10%
# Epoch 93/100, Train loss: 1.4622, Train acc: 46.4286%, Val loss: 2.2168, Val acc: 28.5714%, Best Val loss: 1.9656 Best Val acc: 38.10%
# Epoch 94/100, Train loss: 1.3387, Train acc: 48.8095%, Val loss: 2.1956, Val acc: 33.3333%, Best Val loss: 1.9656 Best Val acc: 38.10%
# Epoch 95/100, Train loss: 1.4185, Train acc: 42.8571%, Val loss: 2.2590, Val acc: 28.5714%, Best Val loss: 1.9656 Best Val acc: 38.10%
# Epoch 96/100, Train loss: 1.5804, Train acc: 34.5238%, Val loss: 2.2677, Val acc: 19.0476%, Best Val loss: 1.9656 Best Val acc: 38.10%
# Epoch 97/100, Train loss: 1.6530, Train acc: 48.8095%, Val loss: 2.3001, Val acc: 28.5714%, Best Val loss: 1.9656 Best Val acc: 38.10%
# Epoch 98/100, Train loss: 1.3701, Train acc: 51.1905%, Val loss: 2.2868, Val acc: 23.8095%, Best Val loss: 1.9656 Best Val acc: 38.10%
# Epoch 99/100, Train loss: 1.3948, Train acc: 48.8095%, Val loss: 2.2435, Val acc: 23.8095%, Best Val loss: 1.9656 Best Val acc: 38.10%
# Epoch 100/100, Train loss: 1.5741, Train acc: 41.6667%, Val loss: 2.2351, Val acc: 23.8095%, Best Val loss: 1.9656 Best Val acc: 38.10%

# %% [markdown]
# ### Visualizing model performance

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2, figsize=(15, 5))

# Plotting training and validation accuracy
ax[0].plot(train_accuracies)
ax[0].plot(val_accuracies)
ax[0].set_title('Model Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(['Train', 'Val'])

# Plotting training and validation loss
ax[1].plot(train_losses)
ax[1].plot(val_losses)
ax[1].set_title('Model Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(['Train', 'Val'])

plt.show()

# %% [markdown]
# ## D. Evaluating Your Trained Model

# %% [markdown]
# ### Load Trained Model and Evaluate

# %%
# Load the trained weights
model.load_state_dict(torch.load('model_classification.pth'))

# Set the model to evaluation mode
model.eval()

test_correct = 0
test_total = 0

with torch.no_grad():
    for images, labels in val_loader:

        images = images.cuda()
        images = (images) / 255.

        labels = labels.cuda()
        labels = labels.long()

        outputs = model(images)

        predicted = outputs.argmax(-1)
        print(predicted)
        print(labels)
        test_correct += (predicted == labels).sum().item()
        test_total += labels.size(0)

print(f'Test accuracy is {100. * test_correct / test_total}%')
# Out:
# tensor([0, 0, 4, 4, 1, 1, 2, 4, 4, 3, 2, 3, 4, 0, 2, 6, 6, 6, 1, 0, 3],
#        device='cuda:0')
# tensor([0, 0, 0, 1, 1, 1, 2, 2, 2, 3, 3, 3, 4, 4, 4, 5, 5, 5, 6, 6, 6],
#        device='cuda:0')
# Test accuracy is 38.095238095238095%

# %%
from torchvision import models

model = models.resnet50()
num_ftrs = model.fc.in_features
num_class = 7
model.fc = nn.Linear(num_ftrs, num_class)

model = models.efficientnet_b1()
num_ftrs = model.classifier[-1].in_features
num_class = 7
model.classifier[-1] = nn.Linear(num_ftrs, num_class)

model = models.vit_b_16()
num_ftrs = model.heads[-1].in_features
model.heads[-1] = nn.Linear(num_ftrs, num_class)
model
# Out:
# VisionTransformer(
#   (conv_proj): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16))
#   (encoder): Encoder(
#     (dropout): Dropout(p=0.0, inplace=False)
#     (layers): Sequential(
#       (encoder_layer_0): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_1): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_2): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_3): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_4): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_5): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_6): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_7): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_8): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_9): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_10): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_11): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (ln): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#   )
#   (heads): Sequential(
#     (head): Linear(in_features=768, out_features=7, bias=True)
#   )
# )
